adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/53678350?adults=1&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/25107574?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/44039117?adults=1&children=0&infants=0&check_in=2022-02-25&check_out=2022-02-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/52626246?adults=1&children=0&infants=0&check_in=2021-12-10&check_out=2021-12-12&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26773229?adults=1&children=0&infants=0&check_in=2022-08-12&check_out=2022-08-14&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/17792518?adults=1&children=0&infants=0&check_in=2022-03-18&check_out=2022-03-20&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/721483?adults=1&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/3385437?adults=1&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33697580?adults=1&children=0&infants=0&check_in=2022-03-04&check_out=2022-03-06&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/8456940?adults=1&children=0&infants=0&check_in=2022-05-13&check_out=2022-05-15&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26433770?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/51263093?adults=1&children=0&infants=0&check_in=2022-10-21&check_out=2022-10-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/29434760?adults=1&children=0&infants=0&check_in=2022-03-11&check_out=2022-03-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/26180556?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/16832733?adults=1&children=0&infants=0&check_in=2022-01-21&check_out=2022-01-23&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/plus/22061939?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/45678598?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/33503897?adults=1&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/43552426?adults=1&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470', 'https://www.airbnb.es/rooms/29066245?adults=1&children=0&infants=0&check_in=2022-01-14&check_out=2022-01-16&previous_page_section_name=1000&federated_search_id=ca4f4c89-c2bc-46ae-b975-eaadf3a3e470']

# %%
len(urls)
# Out:
# 4281

# %%
df = pd.DataFrame(urls)

# %%
df.duplicated().sum()
# Out:
# 3966

# %%
print(urls[100])
# Out:
# https://www.airbnb.es/rooms/505635148600743641?adults=1&children=0&infants=0&check_in=2022-09-16&check_out=2022-09-18&previous_page_section_name=1000&federated_search_id=6e24deb6-0386-4da8-b1ff-d93ecafc9962

# %%
print(urls[302])
# Out:
# https://www.airbnb.es/rooms/39858092?adults=1&children=0&infants=0&check_in=2022-06-03&check_out=2022-06-05&previous_page_section_name=1000&federated_search_id=42b44025-1e8d-4cdd-9f25-2443be9d26d1

# %%
print(urls[602])
# Out:
# https://www.airbnb.es/rooms/28624437?adults=1&children=0&infants=0&check_in=2021-12-17&check_out=2021-12-19&previous_page_section_name=1000&federated_search_id=5560f783-6332-4a0e-b264-b67db4125a71

# %%
print(urls[1508])
# Out:
# https://www.airbnb.es/rooms/1332929?adults=1&children=0&infants=0&check_in=2022-02-11&check_out=2022-02-13&previous_page_section_name=1000&federated_search_id=a7f084e2-93ea-4a7f-a513-1ddc88b02fa6

# %%
urls_ = urls[:50]

# %% [markdown]
# ## Extracción de Datos:

# %%
driver.quit()

# %%
dicc_ = {"all_info": [], "características": [], "precio": [], "fecha": [], "usos": []}
count = 0
for i in urls_:
    print(count)
    driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
    driver.get(i)
    driver.implicitly_wait(2) # is like a time.sleep but specific of selenium  
    
    #acepta las cookies:
    driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div:nth-child(1) > div > div._1cgcei8 > section > div._gsw2t0 > div._160gnkxa > button").click()
    driver.implicitly_wait(2)
    
    #empiezo con la obtención de datos:
    
    #ALL_INFO
    try:
        dicc["all_info"].append(driver.find_element_by_xpath("/html/body/div[5]/div/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[3]/div/div[1]/div/div/main/div[1]/div/div/section/div/div/div/div[1]/ol").text)                                             
        print("llego a los huespedes")
        driver.implicitly_wait(4)
    except:
        dicc["all_info"].append("No hay dato")
    
    #CARACTERÍSTICAS
    try:
        dicc["características"].append(driver.find_element_by_xpath("/html/body/div[5]/div/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[3]/div/div[1]/div/div/main/div[2]/div/div[2]").text)
        print("llego a las características")
        driver.implicitly_wait(4)
    except:
        dicc["características"].append("No hay dato")
    
    
    #PRECIO Y VALORACIÓN:
    try:
        dicc["precio"].append(driver.find_element_by_xpath("/html/body/div[5]/div/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[3]/div/div[2]/div/div/div[1]/div/div/div/div/div/div/div[1]/div[1]").text)
        print("llego a los precios")
        driver.implicitly_wait(4)
    except:
        dicc["precio"].append("No hay dato")
    
    #USOS: 
    try:
        dicc["usos"].append(driver.find_element_by_xpath("/html/body/div[5]/div/div/div[1]/div/div/div/div/div/div[1]/main/div/div[1]/div[3]/div/div[1]/div/div/main/div[5]/div/div[2]").text)
        print("llego a los usos")
        driver.implicitly_wait(4)
    except:
        dicc["usos"].append("No hay dato")
    count += 1
    driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/franciscovispo/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# 0
# <ipython-input-38-0285075b29b1>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-38-0285075b29b1>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("body > div:nth-child(7) > div > div > div:nth-child(1) > div > div._1cgcei8 > section > div._gsw2t0 > div._160gnkxa > button").click()
# <ipython-input-38-0285075b29b1>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...
